# %%
from logo import logo

# %%
# default
# ========================
colors = {}
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#636363'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = '#ADF7FF' # some other blues to try: '#C0F5FA', '#9DD1F1', '#9ED8DB', '#99F5FF', #ADF7FF

logo(f'dept_logo.png', colors)

# %%
# pride
# ========================
colors = {}
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#000000' # dark gray: #292F33, med gray: #636363, light gray: '#9FA3A6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#000000'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#000000'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = ['#D12229', '#F68A1E','#FDE01A','#007940','#24408E','#732982']

logo(f'dept_logo_pride.png', colors, shape='circle')

# %%
# chinese lunar new year
# ========================
colors = {}
colors['popcorn'] = '#FFD84B' # CU gold: '#D4B773'
colors['mountains_edge'] = '#F5AC27' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFECA5'
colors['border'] = '#A3262A'
colors['border_contrast'] = '#FFD84B'
colors['header_tag'] = '#A3262A'
colors['header_text'] = '#FFD84B'
colors['footer_lines'] = '#A3262A'
colors['footer_text'] = '#CC232A'
colors['sky'] = '#CC232A' # some other blues to try: '#C0F5FA', '#9DD1F1', '#9ED8DB', '#99F5FF', #ADF7FF

logo(f'dept_logo_lunar-new-year.png', colors, shape='rectangle', ratio='3:1', dpi=600)

# %%
# monocolor (gold) v2
# ========================
colors = {}
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#D4B773' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#D4B773'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#D4B773'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#FFFFFF'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = '#FFFFFF'

logo(f'dept_logo_monocolor-gold-v2.eps', colors, shape='rounded_rectangle', ratio='3:2', ftype='eps')
