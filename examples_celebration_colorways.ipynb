# %%
from logo import logo

# %%
colors = {}

# %%
# pride colors!
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#000000' # dark gray: #292F33, med gray: #636363, light gray: '#9FA3A6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#000000'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#000000'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = ['#D12229', '#F68A1E','#FDE01A','#007940','#24408E','#732982']

logo('dept_logo_pride.png', colors, ratio='3:2', shape='rounded_rectangle')

# %%
# trans pride colors!
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # dark gray: #292F33, med gray: #636363, light gray: '#9FA3A6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#636363'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = ['#55CDFC', '#F7A8B8', '#FFFFFF', '#F7A8B8', '#55CDFC']

logo('dept_logo_transpride_square.png', colors, ratio='5:4', shape='rounded_rectangle')

# %%
# international women's day colors!
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # dark gray: #292F33, med gray: #636363, light gray: '#9FA3A6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#636363'
colors['border_contrast'] = '#FFCBE6'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = ['#BD1877', '#F8B9D4', '#FFCBE6', '#7E77DD', '#5D48B8']

logo('dept_logo_iwd_square.png', colors, ratio='1:1')

# %%
# earth month
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#705222' # dark gray: #292F33, med gray: #636363, light gray: '#9FA3A6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#705222'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#705222'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#705222'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = ['#93c47d', '#89ba73', '#86dfc4', '#9fc5e8', '#705222']

logo('dept_logo_earth.png', colors, shape='rectangle', ratio='1:1')

# %%
# black history month
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#000000' # dark gray: #292F33, med gray: #636363, light gray: '#9FA3A6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#000000'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#000000'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#292F33'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = ['#ed1e26', '#ecac0a', '#0e7a4e']

logo('dept_logo_blackhistory.png', colors, shape='default', ratio='5:4')

# %%
# asian pacific heritage month
# ========================
colors['popcorn'] = '#fbbb51' # CU gold: '#D4B773'
colors['mountains_edge'] = '#9FA3A6' # dark gray: #292F33, med gray: #636363, light gray: '#9FA3A6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#fbbb51'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#f05c81'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#FFFFFF'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = ['#eab0ce', '#37bcc1', '#f05c81']

logo('dept_logo_aapi.png', colors, shape='circle', ratio='5:4')

# %%
# happy halloween!
# ========================
colors['popcorn'] = '#F4831B' # CU gold: '#D4B773'
colors['mountains_edge'] = '#1C1C1C' # dark gray: #292F33, med gray: #636363, light gray: '#9FA3A6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#1C1C1C'
colors['border_contrast'] = '#F4831B'
colors['header_tag'] = '#1C1C1C'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#FFFFFF'
colors['footer_text'] = '#1C1C1C'
colors['sky'] = ['#902EBB', '#63C328', '#902EBB', '#63C328', '#902EBB', '#63C328']

logo('dept_logo_aapi.png', colors, shape='oval', ratio='5:4')

# %%
# native heritage month
# ========================
colors['popcorn'] = '#f49f0a' # CU gold: '#D4B773'
colors['mountains_edge'] = '#1474aa' # dark gray: #292F33, med gray: #636363, light gray: '#9FA3A6'
colors['mountains_snow'] = '#fa4d0a'
colors['border'] = '#1474aa'
colors['border_contrast'] = '#f3eac2'
colors['header_tag'] = '#fa4d0a'
colors['header_text'] = '#f3eac2'
colors['footer_lines'] = '#fa4d0a'
colors['footer_text'] = '#f3eac2'
colors['sky'] = ['#f3eac2']

logo('dept_logo_aapi.png', colors, shape='rectangle', ratio='3:2')
