# %%
from logo import logo

# %%
colors = {}

# %%
# grayscale
colors['popcorn'] = '#636363' # CU gold: '#D4B773'
colors['mountains_edge'] = '#9FA3A6' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#000000'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#9FA3A6'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = ['#FFFFFF']

logo('dept_logo_grayscale_o_3t2.png', colors, shape='oval', ratio='3:2')

# %%
# grayscale
colors['popcorn'] = '#636363' # CU gold: '#D4B773'
colors['mountains_edge'] = '#9FA3A6' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#000000'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#9FA3A6'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = ['#FFFFFF']

logo('dept_logo_grayscale_rr_1t1.png', colors, shape='rounded_square')

# %%
# only CU colors
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#000000'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = ['#D9D9D9']

logo('dept_logo_cucolors_5t4.png', colors, ratio='5:4')

# %%
# only CU colors
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#000000'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = ['#000000']

logo('dept_logo_cucolors_square.png', colors, shape='square')

# %%
# one color (black)
# ========================
colors['popcorn'] = '#000000' # CU gold: '#D4B773'
colors['mountains_edge'] = '#000000' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#000000'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#000000'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#FFFFFF'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = '#FFFFFF'

logo('dept_logo_black_1t1.png', colors, ratio='1:1')

# %%
# one color (gold)
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#D4B773' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#000000'
colors['border'] = '#000000'
colors['border_contrast'] = '#D4B773'
colors['header_tag'] = '#D4B773'
colors['header_text'] = '#000000'
colors['footer_lines'] = '#000000'
colors['footer_text'] = '#000000'
colors['sky'] = '#000000'

logo('dept_logo_gold.png', colors, shape='rounded_rectangle', ratio='5:4')

# %%
# only CU colors
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#000000'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = ['#FFFFFF']

logo('dept_logo_cucolors_o_5t4.png', colors, ratio='5:4', shape='oval')

# %%
# one color (gold)
# ========================
colors['popcorn'] = '#000000' # CU gold: '#D4B773'
colors['mountains_edge'] = '#000000' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#000000'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#000000'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#FFFFFF'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = '#FFFFFF'

logo('dept_logo_bw.png', colors, shape='rectangle', ratio='3:2')
