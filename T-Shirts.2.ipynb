# %%
from logo_mathstats import logo_mathstats

# %%
fnames = ['3t2_roundrect', '5t4_roundrect', '1t1_roundrect',
          '3t2_oval', '5t4_oval', '1t1_oval',
          '3t2_rect', '5t4_rect', '1t1_rect',
          '3t2_default', '5t4_default', '1t1_default']
ratios = ['3:2', '5:4', '1:1',
          '3:2', '5:4', '1:1',
          '3:2', '5:4', '1:1',
          '3:2', '5:4', '1:1']
shapes = ['rounded_rectangle', 'rounded_rectangle', 'rounded_rectangle',
          'oval', 'oval', 'oval',
          'rectangle', 'rectangle', 'rectangle',
          'default', 'default', 'default']

# %%
# For T-Shirts
# ========================
colors = {}
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#000000' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#000000'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#D4B773'
colors['header_text'] = '#000000'
colors['footer_lines'] = '#000000'
colors['footer_text'] = '#000000'
colors['footer_small_text'] = '#000000'
colors['sky'] = ['#FFFFFF'] # some other blues to try: '#C0F5FA', '#9DD1F1', '#9ED8DB', '#99F5FF', #ADF7FF


for fn, ratio, shape in zip(fnames, ratios, shapes):
    logo_mathstats(f'dept_logo_pride_{fn}.eps',
         colors,
         ratio=ratio,
         shape=shape,
         ftype='eps')
