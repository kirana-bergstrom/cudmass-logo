# %%
from logo import logo

# %%
colors = {}

# %%
# standard version
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#636363'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = '#85E2FF' # some other blues to try: '#C0F5FA', '#9DD1F1', '#9ED8DB'
colors['sky'] = '#ADF7FF' # some other blues to try: '#C0F5FA', '#9DD1F1', '#9ED8DB', '#99F5FF', #ADF7FF

logo('dept_logo_3t2.png', colors, ratio='3:2')

# %%
# standard version
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#636363'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = '#ADF7FF' # some other blues to try: '#C0F5FA', '#9DD1F1', '#9ED8DB'

logo('dept_logo.eps', colors)

# %%
# standard version
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#636363'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = '#ADF7FF' # some other blues to try: '#C0F5FA', '#9DD1F1', '#9ED8DB'

logo('dept_logo_1t1.png', colors, ratio='1:1')

# %%
# standard version
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#636363'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = '#ADF7FF' # some other blues to try: '#C0F5FA', '#9DD1F1', '#9ED8DB'

logo('dept_logo_r_3t2.png', colors, shape='rectangle', ratio='3:2')

# %%
# standard version
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#636363'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = '#ADF7FF' # some other blues to try: '#C0F5FA', '#9DD1F1', '#9ED8DB'

logo('dept_logo_r_5t4.png', colors, shape='rectangle', ratio='5:4')

# %%
# standard version
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#636363'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = '#ADF7FF' # some other blues to try: '#C0F5FA', '#9DD1F1', '#9ED8DB'

logo('dept_logo_r_1t1.png', colors, shape='square')

# %%
# standard version
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#636363'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = '#ADF7FF' # some other blues to try: '#C0F5FA', '#9DD1F1', '#9ED8DB'

logo('dept_logo_o_3t2.png', colors, shape='oval', ratio='3:2')

# %%
# standard version
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#636363'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = '#ADF7FF' # some other blues to try: '#C0F5FA', '#9DD1F1', '#9ED8DB'

logo('dept_logo_o_5t4.png', colors, shape='oval', ratio='5:4')

# %%
# standard version
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#636363'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = '#ADF7FF' # some other blues to try: '#C0F5FA', '#9DD1F1', '#9ED8DB'

logo('dept_logo_o_1t1.png', colors, shape='oval', ratio='1:1')

# %%
# standard version
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#636363'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = '#ADF7FF' # some other blues to try: '#C0F5FA', '#9DD1F1', '#9ED8DB'

logo('dept_logo_rr_3t2.png', colors, shape='rounded_rectangle', ratio='3:2')

# %%
# standard version
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#636363'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = '#ADF7FF' # some other blues to try: '#C0F5FA', '#9DD1F1', '#9ED8DB'

logo('dept_logo_rr_5t4.png', colors, shape='rounded_rectangle', ratio='5:4')

# %%
# standard version
# ========================
colors['popcorn'] = '#D4B773' # CU gold: '#D4B773'
colors['mountains_edge'] = '#636363' # lighter gray: '#9fa3a6'
colors['mountains_snow'] = '#FFFFFF'
colors['border'] = '#636363'
colors['border_contrast'] = '#FFFFFF'
colors['header_tag'] = '#636363'
colors['header_text'] = '#FFFFFF'
colors['footer_lines'] = '#636363'
colors['footer_text'] = '#FFFFFF'
colors['sky'] = '#ADF7FF' # some other blues to try: '#C0F5FA', '#9DD1F1', '#9ED8DB'

logo('dept_logo_rr_1t1.png', colors, shape='rounded_rectangle', ratio='1:1')
